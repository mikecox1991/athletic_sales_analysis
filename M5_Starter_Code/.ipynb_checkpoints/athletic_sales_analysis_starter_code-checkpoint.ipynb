# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
sales_2020_df=pd.read_csv('Resources/athletic_sales_2020.csv')
sales_2021_df=pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
sales_2020_df.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# 2       206250          61875.00       Outlet
# 3        13056           6789.12       Outlet
# 4         4399           1407.68       Outlet

# %%
# Display the 2021 sales DataFrame
sales_2021_df.head()
# Out:
#     retailer  retailer_id invoice_date   region       state           city  \
# 0  West Gear      1128299       1/1/21     West  California  San Francisco
# 1  West Gear      1128299       1/1/21     West  California  San Francisco
# 2     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 3     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 4  West Gear      1128299       1/1/21     West  California  San Francisco
#
#                    product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear              65         750       487500
# 1  Men's Athletic Footwear              51         233        11883
# 2            Men's Apparel              50         275       137500
# 3            Men's Apparel              47          77         3619
# 4  Men's Athletic Footwear              64         225        14400
#
#    operating_profit sales_method
# 0         121875.00       Outlet
# 1           3208.41       Outlet
# 2          82500.00       Outlet
# 3           2714.25       Online
# 4           5184.00       Online

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_df=pd.merge(sales_2020_df, sales_2021_df, on='total_sales', suffixes=("_2020", "_2021"))
combined_df.reset_
# Out:
#       retailer_2020  retailer_id_2020 invoice_date_2020 region_2020  \
# 0       Foot Locker           1185732            1/1/20   Northeast
# 1       Foot Locker           1185732           1/31/20   Northeast
# 2         West Gear           1128299            7/8/20        West
# 3         West Gear           1128299           7/31/20        West
# 4     Sports Direct           1185732           9/29/20   Southeast
# ...             ...               ...               ...         ...
# 9069         Kohl's           1189833          12/28/20     Midwest
# 9070      West Gear           1128299          12/29/20        West
# 9071      West Gear           1128299          12/30/20        West
# 9072      West Gear           1128299          12/30/20        West
# 9073      West Gear           1128299          12/30/20        West
#
#       state_2020      city_2020             product_2020  price_per_unit_2020  \
# 0       New York       New York    Men's Street Footwear                   50
# 1       New York       New York    Men's Street Footwear                   50
# 2     Washington        Seattle  Men's Athletic Footwear                   80
# 3     Washington        Seattle    Men's Street Footwear                   80
# 4        Florida          Miami    Men's Street Footwear                   60
# ...          ...            ...                      ...                  ...
# 9069   Minnesota    Minneapolis    Men's Street Footwear                   32
# 9070  California  San Francisco            Men's Apparel                   47
# 9071  California  San Francisco          Women's Apparel                   80
# 9072  California  San Francisco          Women's Apparel                   80
# 9073  California  San Francisco          Women's Apparel                   80
#
#       units_sold_2020  total_sales  ...  retailer_id_2021 invoice_date_2021  \
# 0                1200       600000  ...           1128299          12/16/21
# 1                1200       600000  ...           1128299          12/16/21
# 2                 750       600000  ...           1128299          12/16/21
# 3                 750       600000  ...           1128299          12/16/21
# 4                1000       600000  ...           1128299          12/16/21
# ...               ...          ...  ...               ...               ...
# 9069              119         3808  ...           1185732           12/6/21
# 9070              158         7426  ...           1185732           7/15/21
# 9071              700       560000  ...           1128299           2/16/21
# 9072              700       560000  ...           1128299           8/17/21
# 9073              700       560000  ...           1128299          12/16/21
#
#      region_2021    state_2021      city_2021               product_2021  \
# 0      Southeast       Florida        Orlando      Men's Street Footwear
# 1      Southeast       Florida        Orlando      Men's Street Footwear
# 2      Southeast       Florida        Orlando      Men's Street Footwear
# 3      Southeast       Florida        Orlando      Men's Street Footwear
# 4      Southeast       Florida        Orlando      Men's Street Footwear
# ...          ...           ...            ...                        ...
# 9069   Northeast  Rhode Island     Providence              Men's Apparel
# 9070     Midwest      Michigan        Detroit  Women's Athletic Footwear
# 9071        West    California  San Francisco            Women's Apparel
# 9072   Southeast       Florida        Orlando    Women's Street Footwear
# 9073       South     Louisiana    New Orleans      Men's Street Footwear
#
#      price_per_unit_2021 units_sold_2021 operating_profit_2021  \
# 0                     75             800             180000.00
# 1                     75             800             180000.00
# 2                     75             800             180000.00
# 3                     75             800             180000.00
# 4                     75             800             180000.00
# ...                  ...             ...                   ...
# 9069                  56              68               1637.44
# 9070                  47             158               3341.70
# 9071                  70             800              56000.00
# 9072                  80             700             168000.00
# 9073                  70             800             224000.00
#
#       sales_method_2021
# 0              In-store
# 1              In-store
# 2              In-store
# 3              In-store
# 4              In-store
# ...                 ...
# 9069             Online
# 9070             Online
# 9071             Outlet
# 9072           In-store
# 9073             Online
#
# [9074 rows x 23 columns]

# %%
# Check if any values are null.
null_sum=combined_df.isnull().sum()
null_sum
# Out:
# total_sales    7049
# total_sales       0
# dtype: int64

# %%
# Check the data type of each column

# %%
# Convert the "invoice_date" to a datetime datatype

# %%
# Confirm that the "invoice_date" data type has been changed.

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".




# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.


# Rename the "units_sold" column to "Total_Products_Sold"


# Show the top 5 results.

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in ascending order on "Total Sales".

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
